# %%
class Node:
    def __init__(self, data=None, next=None, prev=None):
        self.data = data
        self.next = next
        self.prev = prev

# %%
class DoubleLinkedList:
    def __init__(self):
        self.head = None
    
    def print_forward(self):
        if self.head is None:
            print("Double linked list is empty")
            return
        
        itr = self.head
        dllstr = ''
        while itr:
            dllstr += str(itr.data) + ' --> '
            itr = itr.next
        print("Double link list forward: ", dllstr)

    def get_last_node(self):
        itr = self.head
        while itr.next:
            itr = itr.next
        return itr

    def print_backward(self):
        if self.head is None:
            print("Double linked list is empty")
            return
        last_node = self.get_last_node()
        itr = last_node
        dllstr = ''
        while itr:
            dllstr += str(itr.data) + ' --> '
            itr = itr.prev
        print("Double link list in reverse: ", dllstr)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count
    
    def insert_at_beginning(self, data):
        if self.head is None:
            node = Node(data, self.head, None)
            return
        node = Node(data, self.head, None)
        self.head.prev = node
        self.head = node

    def insert_at_end(self, data):
        if self.head is None:
            self.head = Node(data, None, None)
            return

        itr = self.head

        while itr.next:
            itr = itr.next

        itr.next = Node(data, None, itr)

    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.insert_at_beginning(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = Node(data, itr.next, itr)
                if node.next:
                    node.next.prev = node
                itr.next = node
                break

            itr = itr.next
            count += 1

    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.head = self.head.next
            self.head.prev = None
            return

        count = 0
        itr = self.head
        while itr:
            if count == index:
                itr.prev.next = itr.next
                if itr.next:
                    itr.next.prev = itr.prev
                break

            itr = itr.next
            count+=1

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
    
    def insert_after_value(self, data_after, data_to_insert):
        # Search for first occurance of data_after value in linked list
        itr = self.head
        while itr:
            if itr.data == data_after:
                # Now insert data_to_insert after data_after node
                node = Node(data_to_insert, itr.next, itr)
                if node.next:
                    node.next.prev = node
                itr.next = node
                break
            itr = itr.next
    
    def remove_by_value(self, data):
        if self.head.data == data:
            self.head = self.head.next
            self.head.prev = None
            return
        
        itr = self.head
        while itr:
            if itr.data == data:
                itr.prev.next = itr.next
                if itr.next:
                    itr.next.prev = itr.prev
                break
            itr = itr.next

# %%
if __name__ == '__main__':
    dll = DoubleLinkedList()
    dll.print_forward()
    dll.insert_values(["orange","banana","mango","grape"])
    dll.print_forward()
    dll.print_backward()
    print(dll.get_length())
    dll.insert_at_beginning("apple")
    dll.print_forward()
    dll.print_backward()
    dll.insert_at_end("pear")
    dll.print_forward()
    dll.print_backward()
    dll.insert_at(5,"melon")
    dll.print_forward()
    dll.print_backward()
    dll.remove_at(5)
    dll.print_forward()
    dll.print_backward()
    dll.insert_after_value("mango","apple") # insert apple after mango
    dll.print_forward()
    dll.print_backward()
    dll.remove_by_value("mango") # remove orange from linked list
    dll.print_forward()
    dll.print_backward()
# Out:
# Double linked list is empty
# Double link list forward:  orange --> banana --> mango --> grape -->
# Double link list in reverse:  grape --> mango --> banana --> orange -->
# 4
# Double link list forward:  apple --> orange --> banana --> mango --> grape -->
# Double link list in reverse:  grape --> mango --> banana --> orange --> apple -->
# Double link list forward:  apple --> orange --> banana --> mango --> grape --> pear -->
# Double link list in reverse:  pear --> grape --> mango --> banana --> orange --> apple -->
# Double link list forward:  apple --> orange --> banana --> mango --> grape --> melon --> pear -->
# Double link list in reverse:  pear --> melon --> grape --> mango --> banana --> orange --> apple -->
# Double link list forward:  apple --> orange --> banana --> mango --> grape --> pear -->
# Double link list in reverse:  pear --> grape --> mango --> banana --> orange --> apple -->
# ...
